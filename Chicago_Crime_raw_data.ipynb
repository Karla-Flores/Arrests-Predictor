# %%
# Dependencies and set up
import pandas as pd
import numpy as np

# %%
# Reading csv
table = pd.read_csv('Resources/Crimes_-_2001_to_Present.csv')
table
# Out:
#                ID Case Number                    Date                  Block  \
# 0        10224738    HY411648  09/05/2015 01:30:00 PM        043XX S WOOD ST
# 1        10224739    HY411615  09/04/2015 11:30:00 AM    008XX N CENTRAL AVE
# 2        11646166    JC213529  09/01/2018 12:01:00 AM  082XX S INGLESIDE AVE
# 3        10224740    HY411595  09/05/2015 12:45:00 PM      035XX W BARRY AVE
# 4        10224741    HY411610  09/05/2015 01:00:00 PM    0000X N LARAMIE AVE
# ...           ...         ...                     ...                    ...
# 7406205  12487794    JE380159  09/19/2021 11:52:00 PM      064XX S MOZART ST
# 7406206  12487637    JE379677  09/19/2021 02:30:00 PM   018XX W CULLERTON ST
# 7406207  12494028    JE387722  09/14/2021 01:00:00 PM        020XX E 83RD ST
# 7406208  12487336    JE379561  09/19/2021 12:30:00 AM    119XX S CALUMET AVE
# 7406209  12487014    JE379294  09/19/2021 08:20:00 AM        001XX E 49TH ST
#
# ...

# %%
# Primary type value counts
table.value_counts(subset=['Primary Type'])
# Out:
# Primary Type
# THEFT                                1558131
# BATTERY                              1358490
# CRIMINAL DAMAGE                       844453
# NARCOTICS                             739154
# ASSAULT                               474426
# OTHER OFFENSE                         460461
# BURGLARY                              412164
# MOTOR VEHICLE THEFT                   341368
# DECEPTIVE PRACTICE                    317753
# ROBBERY                               277897
# CRIMINAL TRESPASS                     207584
# WEAPONS VIOLATION                      92805
# PROSTITUTION                           69443
# OFFENSE INVOLVING CHILDREN             52098
# PUBLIC PEACE VIOLATION                 51194
# SEX OFFENSE                            28587
# CRIM SEXUAL ASSAULT                    27841
# INTERFERENCE WITH PUBLIC OFFICER       17725
# GAMBLING                               14603
# LIQUOR LAW VIOLATION                   14564
# ...

# %%
# Dropping NA
table.dropna(inplace=True)
table.shape
# Out:
# (6719641, 22)

# %%
# Replacing primary types
table.loc[table['Primary Type'] == 'OBSCENITY'] = 'OTHER'
table.loc[table['Primary Type'] == 'PUBLIC INDECENCY'] = 'OTHER'
table.loc[table['Primary Type'] == 'NON-CRIMINAL'] = 'OTHER'
table.loc[table['Primary Type'] == 'OTHER NARCOTIC VIOLATION'] = 'OTHER'
table.loc[table['Primary Type'] == 'HUMAN TRAFFICKING'] = 'OTHER'
table.loc[table['Primary Type'] == 'NON - CRIMINAL'] = 'OTHER'
table.loc[table['Primary Type'] == 'RITUALISM'] = 'OTHER'
table.loc[table['Primary Type'] == 'NON-CRIMINAL (SUBJECT SPECIFIED)'] = 'OTHER'
table.loc[table['Primary Type'] == 'DOMESTIC VIOLENCE'] = 'OTHER'
table.loc[table['Primary Type'] == 'CONCEALED CARRY LICENSE VIOLATION'] = 'OTHER'

# %%
# Primary type value counts
table.value_counts(subset=['Primary Type'])
# Out:
# Primary Type
# THEFT                               1418020
# BATTERY                             1235838
# CRIMINAL DAMAGE                      769589
# NARCOTICS                            662550
# ASSAULT                              433133
# OTHER OFFENSE                        417774
# BURGLARY                             378325
# MOTOR VEHICLE THEFT                  305815
# DECEPTIVE PRACTICE                   280739
# ROBBERY                              253601
# CRIMINAL TRESPASS                    189311
# WEAPONS VIOLATION                     86875
# PROSTITUTION                          60952
# PUBLIC PEACE VIOLATION                47586
# OFFENSE INVOLVING CHILDREN            46470
# SEX OFFENSE                           24494
# CRIM SEXUAL ASSAULT                   24322
# INTERFERENCE WITH PUBLIC OFFICER      17156
# GAMBLING                              13390
# LIQUOR LAW VIOLATION                  12450
# ARSON                                 11165
# ...

# %%
# Columns
list(table.columns)
# Out:
# ['ID',
#  'Case Number',
#  'Date',
#  'Block',
#  'IUCR',
#  'Primary Type',
#  'Description',
#  'Location Description',
#  'Arrest',
#  'Domestic',
#  'Beat',
#  'District',
#  'Ward',
#  'Community Area',
#  'FBI Code',
#  'X Coordinate',
#  'Y Coordinate',
#  'Year',
#  'Updated On',
#  'Latitude',
#  'Longitude',
#  'Location']

# %%
# Dropping columns
table.drop(['ID', 'Case Number', 'Updated On', 'Location', 'Ward', 'Community Area', 'Beat'], axis = 1, inplace = True)
list(table.columns)
# Out:
# ['Date',
#  'Block',
#  'IUCR',
#  'Primary Type',
#  'Description',
#  'Location Description',
#  'Arrest',
#  'Domestic',
#  'District',
#  'FBI Code',
#  'X Coordinate',
#  'Y Coordinate',
#  'Year',
#  'Latitude',
#  'Longitude']

# %%
# Primary type value counts
lc_table = table['Location Description']
lc_table
# Out:
# 0          RESIDENCE
# 1            CTA BUS
# 3           SIDEWALK
# 4          APARTMENT
# 5          RESIDENCE
#              ...
# 7406204    RESIDENCE
# 7406205     SIDEWALK
# 7406206    APARTMENT
# 7406208       STREET
# 7406209        ALLEY
# Name: Location Description, Length: 6719641, dtype: object
